# %% [markdown]
# ### Reqirements
# - keras >= 2.2.0 or tensorflow >= 1.13
# - segmenation-models==1.0.*
# - albumentations==0.3.0

# %%
# Install required libs

### please update Albumentations to version>=0.3.0 for `Lambda` transform support
# %env SM_FRAMEWORK=tf.keras
#!pip install -U albumentations>=0.3.0 --user 
#!pip install -U --pre segmentation-models --user
# Out:
# env: SM_FRAMEWORK=tf.keras

# %% [markdown]
# # Loading dataset

# %%
import os

import cv2
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
from segmentation_models.utils import set_trainable
import tensorflow as tf

# %%
DATA_DIR = r'C:\Users\Gabriel\OneDrive - Universidade de Tras-os-Montes e Alto Douro\UTAD\2020-2021\Pesquisa\Dataset\teste_masks_crop3'

# %%
#load the images and annotations

x_train_dir = os.path.join(DATA_DIR, 'train', 'image')
y_train_dir = os.path.join(DATA_DIR, 'train', 'mask')

x_valid_dir = os.path.join(DATA_DIR, 'validation', 'image')
y_valid_dir = os.path.join(DATA_DIR, 'validation', 'mask')

x_test_dir = os.path.join(DATA_DIR, 'test', 'image')
y_test_dir = os.path.join(DATA_DIR, 'test', 'mask')

#define the images' size 
target_size = (320, 320)

# %% [markdown]
# # Dataloader and utility functions

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'leaves']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        #modifiying to read images in png format
        self.masks_fps = [os.path.join(masks_dir, image_id.split('.')[0]+'.png') for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return tuple(batch)
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'leaves'])

image, mask = dataset[4] # get some sample

visualize(
    image=image, 
    background_mask=mask[..., 0].squeeze(),
    leaves_mask=mask[..., 1].squeeze()
)

# %% [markdown]
# ### Augmentations

# %% [markdown]
# Data augmentation is a powerful technique to increase the amount of your data and prevent model overfitting.
# If you not familiar with such trick read some of these articles:
#  - [The Effectiveness of Data Augmentation in Image Classification using Deep
# Learning](http://cs231n.stanford.edu/reports/2017/pdfs/300.pdf)
#  - [Data Augmentation | How to use Deep Learning when you have Limited Data](https://medium.com/nanonets/how-to-use-deep-learning-when-you-have-limited-data-part-2-data-augmentation-c26971dc8ced)
#  - [Data Augmentation Experimentation](https://towardsdatascience.com/data-augmentation-experimentation-3e274504f04b)
#
# Since our dataset is very small we will apply a large number of different augmentations:
#  - horizontal flip
#  - affine transforms
#  - perspective transforms
#  - brightness/contrast/colors manipulations
#  - image bluring and sharpening
#  - gaussian noise
#  - random crops
#
# All this transforms can be easily applied with [**Albumentations**](https://github.com/albu/albumentations/) - fast augmentation library.
# For detailed explanation of image transformations you can look at [kaggle salt segmentation exmaple](https://github.com/albu/albumentations/blob/master/notebooks/example_kaggle_salt.ipynb) provided by [**Albumentations**](https://github.com/albu/albumentations/) authors.

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=target_size[0], min_width=target_size[1], always_apply=True, border_mode=0),
        A.RandomCrop(height=target_size[0], width=target_size[1], always_apply=True),

        A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.IAASharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(target_size[0], target_size[1]),
        A.Resize(target_size[0], target_size[1])
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'leaves'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background_mask=mask[..., 0].squeeze(),
    leaves_mask=mask[..., 1].squeeze()
)

# %% [markdown]
# # Segmentation model training

# %%
import segmentation_models as sm

# segmentation_models could also use `tf.keras` if you do not have Keras installed
# or you could switch to other framework using `sm.set_framework('tf.keras')`

# %%
BACKBONE = 'efficientnetb3'
BATCH_SIZE = 8
CLASSES = ['leaves']
LR = 0.0001
EPOCHS = 50

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

with tf.device('/gpu:1'):
    #create model
    model = sm.Unet(BACKBONE, input_shape=(target_size[0],target_size[1],3), classes=n_classes, activation=activation, encoder_freeze=True)
    # define optomizer
    optim = keras.optimizers.Adam(LR)

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = sm.losses.DiceLoss()
    focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
    total_loss = dice_loss + (1 * focal_loss)

    # actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
    # total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

    # compile keras model with defined optimozer, loss and metrics
    model.compile(optim, total_loss, metrics)

    # Dataset for train images
    train_dataset = Dataset(
        x_train_dir, 
        y_train_dir, 
        classes=CLASSES, 
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    # Dataset for validation images
    valid_dataset = Dataset(
        x_valid_dir, 
        y_valid_dir, 
        classes=CLASSES, 
        augmentation=get_validation_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

    # check shapes for errors
    assert train_dataloader[0][0].shape == (BATCH_SIZE, target_size[0], target_size[1], 3)
    assert train_dataloader[0][1].shape == (BATCH_SIZE, target_size[0], target_size[1], n_classes)

    # define callbacks for learning rate scheduling and best checkpoints saving
    callbacks = [
        keras.callbacks.ModelCheckpoint('best_model.h5', save_weights_only=True, save_best_only=True, monitor = 'val_iou_score',mode='max',verbose=1),
        keras.callbacks.ReduceLROnPlateau(monitor='val_iou_score', factor=0.95, patience=2, verbose=1, mode='max', cooldown=1, min_lr=0.000001),
    ]

    # train model
    history = model.fit_generator(
        train_dataloader, 
        steps_per_epoch=len(train_dataloader), 
        epochs=EPOCHS, 
        callbacks=callbacks, 
        validation_data=valid_dataloader, 
        validation_steps=len(valid_dataloader),
    )

    #retrain now the entire model
    set_trainable(model,recompile=False)
    #decrase the LR 
    optim = keras.optimizers.Adam(LR/100.0)

    #recompile the model
    model.compile(optim, total_loss, metrics)

    #retrain
    history = model.fit_generator(
        train_dataloader, 
        steps_per_epoch=len(train_dataloader), 
        epochs=EPOCHS, 
        callbacks=callbacks, 
        validation_data=valid_dataloader, 
        validation_steps=len(valid_dataloader),
    )
# Out:
# Epoch 1/50
# 662/662 [==============================] - 613s 888ms/step - loss: 0.2075 - iou_score: 0.8697 - f1-score: 0.9263 - val_loss: 0.1617 - val_iou_score: 0.8891 - val_f1-score: 0.9331
#
# Epoch 00001: val_iou_score improved from -inf to 0.88906, saving model to best_model.h5
# Epoch 2/50
# 662/662 [==============================] - 581s 878ms/step - loss: 0.1794 - iou_score: 0.8828 - f1-score: 0.9341 - val_loss: 0.1460 - val_iou_score: 0.9006 - val_f1-score: 0.9414
#
# Epoch 00002: val_iou_score improved from 0.88906 to 0.90059, saving model to best_model.h5
# Epoch 3/50
# 662/662 [==============================] - 579s 874ms/step - loss: 0.1702 - iou_score: 0.8891 - f1-score: 0.9376 - val_loss: 0.1492 - val_iou_score: 0.8987 - val_f1-score: 0.9407
#
# Epoch 00003: val_iou_score did not improve from 0.90059
# Epoch 4/50
# 662/662 [==============================] - 577s 872ms/step - loss: 0.1612 - iou_score: 0.8942 - f1-score: 0.9406 - val_loss: 0.1364 - val_iou_score: 0.9093 - val_f1-score: 0.9475
#
# Epoch 00004: val_iou_score improved from 0.90059 to 0.90926, saving model to best_model.h5
# Epoch 5/50
# 662/662 [==============================] - 578s 874ms/step - loss: 0.1533 - iou_score: 0.8981 - f1-score: 0.9433 - val_loss: 0.1418 - val_iou_score: 0.8956 - val_f1-score: 0.9386
#
# Epoch 00005: val_iou_score did not improve from 0.90926
# Epoch 6/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.1446 - iou_score: 0.9023 - f1-score: 0.9458 - val_loss: 0.1452 - val_iou_score: 0.9029 - val_f1-score: 0.9422
#
# Epoch 00006: val_iou_score did not improve from 0.90926
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.499999760009814e-05.
# Epoch 7/50
# 662/662 [==============================] - 578s 873ms/step - loss: 0.1404 - iou_score: 0.9042 - f1-score: 0.9468 - val_loss: 0.1443 - val_iou_score: 0.8827 - val_f1-score: 0.9307
#
# Epoch 00007: val_iou_score did not improve from 0.90926
# Epoch 8/50
# 662/662 [==============================] - 579s 874ms/step - loss: 0.1338 - iou_score: 0.9088 - f1-score: 0.9495 - val_loss: 0.1388 - val_iou_score: 0.8835 - val_f1-score: 0.9311
#
# Epoch 00008: val_iou_score did not improve from 0.90926
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 9.02499959920533e-05.
# Epoch 9/50
# 662/662 [==============================] - 583s 880ms/step - loss: 0.1300 - iou_score: 0.9110 - f1-score: 0.9508 - val_loss: 0.1275 - val_iou_score: 0.9090 - val_f1-score: 0.9475
#
# Epoch 00009: val_iou_score did not improve from 0.90926
# Epoch 10/50
# 662/662 [==============================] - 582s 880ms/step - loss: 0.1251 - iou_score: 0.9141 - f1-score: 0.9530 - val_loss: 0.1391 - val_iou_score: 0.8886 - val_f1-score: 0.9340
#
# Epoch 00010: val_iou_score did not improve from 0.90926
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 8.573749619245064e-05.
# Epoch 11/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1234 - iou_score: 0.9147 - f1-score: 0.9530 - val_loss: 0.1307 - val_iou_score: 0.9100 - val_f1-score: 0.9477
#
# Epoch 00011: val_iou_score improved from 0.90926 to 0.90998, saving model to best_model.h5
# Epoch 12/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.1207 - iou_score: 0.9149 - f1-score: 0.9531 - val_loss: 0.1338 - val_iou_score: 0.9025 - val_f1-score: 0.9431
#
# Epoch 00012: val_iou_score did not improve from 0.90998
# Epoch 13/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.1193 - iou_score: 0.9159 - f1-score: 0.9536 - val_loss: 0.1300 - val_iou_score: 0.9042 - val_f1-score: 0.9444
#
# Epoch 00013: val_iou_score did not improve from 0.90998
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 8.145062311086804e-05.
# Epoch 14/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1196 - iou_score: 0.9156 - f1-score: 0.9534 - val_loss: 0.1268 - val_iou_score: 0.9148 - val_f1-score: 0.9512
#
# Epoch 00014: val_iou_score improved from 0.90998 to 0.91477, saving model to best_model.h5
# Epoch 15/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1191 - iou_score: 0.9159 - f1-score: 0.9536 - val_loss: 0.1292 - val_iou_score: 0.9072 - val_f1-score: 0.9462
#
# Epoch 00015: val_iou_score did not improve from 0.91477
# Epoch 16/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1125 - iou_score: 0.9192 - f1-score: 0.9557 - val_loss: 0.1335 - val_iou_score: 0.9125 - val_f1-score: 0.9495
#
# Epoch 00016: val_iou_score did not improve from 0.91477
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 7.737808919046074e-05.
# Epoch 17/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.1103 - iou_score: 0.9216 - f1-score: 0.9572 - val_loss: 0.1245 - val_iou_score: 0.9096 - val_f1-score: 0.9479
#
# Epoch 00017: val_iou_score did not improve from 0.91477
# Epoch 18/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.1116 - iou_score: 0.9193 - f1-score: 0.9558 - val_loss: 0.1241 - val_iou_score: 0.9042 - val_f1-score: 0.9444
#
# Epoch 00018: val_iou_score did not improve from 0.91477
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 7.350918749580159e-05.
# Epoch 19/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1085 - iou_score: 0.9229 - f1-score: 0.9578 - val_loss: 0.1292 - val_iou_score: 0.8965 - val_f1-score: 0.9393
#
# Epoch 00019: val_iou_score did not improve from 0.91477
# Epoch 20/50
# 662/662 [==============================] - 580s 877ms/step - loss: 0.1102 - iou_score: 0.9211 - f1-score: 0.9566 - val_loss: 0.1335 - val_iou_score: 0.8943 - val_f1-score: 0.9375
#
# Epoch 00020: val_iou_score did not improve from 0.91477
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.983372950344346e-05.
# Epoch 21/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1081 - iou_score: 0.9218 - f1-score: 0.9575 - val_loss: 0.1183 - val_iou_score: 0.9165 - val_f1-score: 0.9521
#
# Epoch 00021: val_iou_score improved from 0.91477 to 0.91654, saving model to best_model.h5
# Epoch 22/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1067 - iou_score: 0.9231 - f1-score: 0.9580 - val_loss: 0.1179 - val_iou_score: 0.9143 - val_f1-score: 0.9509
#
# Epoch 00022: val_iou_score did not improve from 0.91654
# Epoch 23/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1051 - iou_score: 0.9238 - f1-score: 0.9580 - val_loss: 0.1509 - val_iou_score: 0.8646 - val_f1-score: 0.9168
#
# Epoch 00023: val_iou_score did not improve from 0.91654
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 6.634204510191921e-05.
# Epoch 24/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1081 - iou_score: 0.9231 - f1-score: 0.9578 - val_loss: 0.1301 - val_iou_score: 0.8912 - val_f1-score: 0.9357
#
# Epoch 00024: val_iou_score did not improve from 0.91654
# Epoch 25/50
# 662/662 [==============================] - 581s 877ms/step - loss: 0.1052 - iou_score: 0.9244 - f1-score: 0.9588 - val_loss: 0.1269 - val_iou_score: 0.9009 - val_f1-score: 0.9424
#
# Epoch 00025: val_iou_score did not improve from 0.91654
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 6.302494111878331e-05.
# Epoch 26/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1015 - iou_score: 0.9257 - f1-score: 0.9596 - val_loss: 0.1202 - val_iou_score: 0.9203 - val_f1-score: 0.9545
#
# Epoch 00026: val_iou_score improved from 0.91654 to 0.92034, saving model to best_model.h5
# Epoch 27/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1002 - iou_score: 0.9268 - f1-score: 0.9601 - val_loss: 0.1297 - val_iou_score: 0.9181 - val_f1-score: 0.9530
#
# Epoch 00027: val_iou_score did not improve from 0.92034
# Epoch 28/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.1067 - iou_score: 0.9251 - f1-score: 0.9587 - val_loss: 0.1185 - val_iou_score: 0.9143 - val_f1-score: 0.9508
#
# Epoch 00028: val_iou_score did not improve from 0.92034
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 5.9873694408452134e-05.
# Epoch 29/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.1022 - iou_score: 0.9274 - f1-score: 0.9603 - val_loss: 0.1314 - val_iou_score: 0.9148 - val_f1-score: 0.9509
#
# Epoch 00029: val_iou_score did not improve from 0.92034
# Epoch 30/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.1006 - iou_score: 0.9262 - f1-score: 0.9598 - val_loss: 0.1212 - val_iou_score: 0.9067 - val_f1-score: 0.9459
#
# Epoch 00030: val_iou_score did not improve from 0.92034
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 5.68800103792455e-05.
# Epoch 31/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0959 - iou_score: 0.9298 - f1-score: 0.9619 - val_loss: 0.1132 - val_iou_score: 0.9187 - val_f1-score: 0.9536
#
# Epoch 00031: val_iou_score did not improve from 0.92034
# Epoch 32/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0955 - iou_score: 0.9298 - f1-score: 0.9618 - val_loss: 0.1163 - val_iou_score: 0.9139 - val_f1-score: 0.9507
#
# Epoch 00032: val_iou_score did not improve from 0.92034
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 5.4036009169067255e-05.
# Epoch 33/50
# 662/662 [==============================] - 581s 877ms/step - loss: 0.0946 - iou_score: 0.9300 - f1-score: 0.9622 - val_loss: 0.1176 - val_iou_score: 0.9144 - val_f1-score: 0.9509
#
# Epoch 00033: val_iou_score did not improve from 0.92034
# Epoch 34/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0951 - iou_score: 0.9303 - f1-score: 0.9622 - val_loss: 0.1214 - val_iou_score: 0.9061 - val_f1-score: 0.9455
#
# Epoch 00034: val_iou_score did not improve from 0.92034
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 5.133420836500591e-05.
# Epoch 35/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.0940 - iou_score: 0.9306 - f1-score: 0.9622 - val_loss: 0.1262 - val_iou_score: 0.9146 - val_f1-score: 0.9510
#
# Epoch 00035: val_iou_score did not improve from 0.92034
# Epoch 36/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0960 - iou_score: 0.9299 - f1-score: 0.9617 - val_loss: 0.1198 - val_iou_score: 0.9157 - val_f1-score: 0.9519
#
# Epoch 00036: val_iou_score did not improve from 0.92034
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 4.876749881077558e-05.
# Epoch 37/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0931 - iou_score: 0.9316 - f1-score: 0.9628 - val_loss: 0.1187 - val_iou_score: 0.9109 - val_f1-score: 0.9488
#
# Epoch 00037: val_iou_score did not improve from 0.92034
# Epoch 38/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.0909 - iou_score: 0.9333 - f1-score: 0.9640 - val_loss: 0.1199 - val_iou_score: 0.9072 - val_f1-score: 0.9463
#
# Epoch 00038: val_iou_score did not improve from 0.92034
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 4.63291238702368e-05.
# Epoch 39/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0912 - iou_score: 0.9326 - f1-score: 0.9634 - val_loss: 0.1198 - val_iou_score: 0.9036 - val_f1-score: 0.9438
#
# Epoch 00039: val_iou_score did not improve from 0.92034
# Epoch 40/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0919 - iou_score: 0.9304 - f1-score: 0.9623 - val_loss: 0.1146 - val_iou_score: 0.9176 - val_f1-score: 0.9530
#
# Epoch 00040: val_iou_score did not improve from 0.92034
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 4.4012669059156905e-05.
# Epoch 41/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0910 - iou_score: 0.9326 - f1-score: 0.9635 - val_loss: 0.1152 - val_iou_score: 0.9109 - val_f1-score: 0.9488
#
# Epoch 00041: val_iou_score did not improve from 0.92034
# Epoch 42/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0930 - iou_score: 0.9318 - f1-score: 0.9628 - val_loss: 0.1166 - val_iou_score: 0.9105 - val_f1-score: 0.9484
#
# Epoch 00042: val_iou_score did not improve from 0.92034
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.181203439657111e-05.
# Epoch 43/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0901 - iou_score: 0.9331 - f1-score: 0.9639 - val_loss: 0.1260 - val_iou_score: 0.9075 - val_f1-score: 0.9465
#
# Epoch 00043: val_iou_score did not improve from 0.92034
# Epoch 44/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.0887 - iou_score: 0.9343 - f1-score: 0.9643 - val_loss: 0.1167 - val_iou_score: 0.9184 - val_f1-score: 0.9534
#
# Epoch 00044: val_iou_score did not improve from 0.92034
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 3.9721430948702614e-05.
# Epoch 45/50
# 662/662 [==============================] - 580s 875ms/step - loss: 0.0888 - iou_score: 0.9344 - f1-score: 0.9646 - val_loss: 0.1141 - val_iou_score: 0.9172 - val_f1-score: 0.9527
#
# Epoch 00045: val_iou_score did not improve from 0.92034
# Epoch 46/50
# 662/662 [==============================] - 581s 877ms/step - loss: 0.0906 - iou_score: 0.9335 - f1-score: 0.9638 - val_loss: 0.1236 - val_iou_score: 0.9057 - val_f1-score: 0.9454
#
# Epoch 00046: val_iou_score did not improve from 0.92034
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 3.773536009248346e-05.
# Epoch 47/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0864 - iou_score: 0.9354 - f1-score: 0.9652 - val_loss: 0.1183 - val_iou_score: 0.9135 - val_f1-score: 0.9503
#
# Epoch 00047: val_iou_score did not improve from 0.92034
# Epoch 48/50
# 662/662 [==============================] - 580s 877ms/step - loss: 0.0879 - iou_score: 0.9351 - f1-score: 0.9648 - val_loss: 0.1166 - val_iou_score: 0.9148 - val_f1-score: 0.9510
#
# Epoch 00048: val_iou_score did not improve from 0.92034
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 3.584859277907526e-05.
# Epoch 49/50
# 662/662 [==============================] - 579s 875ms/step - loss: 0.0867 - iou_score: 0.9339 - f1-score: 0.9642 - val_loss: 0.1140 - val_iou_score: 0.9182 - val_f1-score: 0.9533
#
# Epoch 00049: val_iou_score did not improve from 0.92034
# Epoch 50/50
# 662/662 [==============================] - 580s 876ms/step - loss: 0.0902 - iou_score: 0.9332 - f1-score: 0.9637 - val_loss: 0.1149 - val_iou_score: 0.9215 - val_f1-score: 0.9553
#
# Epoch 00050: val_iou_score improved from 0.92034 to 0.92155, saving model to best_model.h5
# Epoch 1/50
# 662/662 [==============================] - 870s 1s/step - loss: 0.0838 - iou_score: 0.9361 - f1-score: 0.9654 - val_loss: 0.1156 - val_iou_score: 0.9121 - val_f1-score: 0.9496
#
# Epoch 00001: val_iou_score did not improve from 0.92155
# Epoch 2/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0822 - iou_score: 0.9382 - f1-score: 0.9666 - val_loss: 0.1129 - val_iou_score: 0.9163 - val_f1-score: 0.9522
#
# Epoch 00002: val_iou_score did not improve from 0.92155
# Epoch 3/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0832 - iou_score: 0.9374 - f1-score: 0.9662 - val_loss: 0.1149 - val_iou_score: 0.9136 - val_f1-score: 0.9505
#
# Epoch 00003: val_iou_score did not improve from 0.92155
# Epoch 4/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0828 - iou_score: 0.9378 - f1-score: 0.9664 - val_loss: 0.1126 - val_iou_score: 0.9165 - val_f1-score: 0.9523
#
# Epoch 00004: val_iou_score did not improve from 0.92155
# Epoch 5/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0836 - iou_score: 0.9369 - f1-score: 0.9659 - val_loss: 0.1136 - val_iou_score: 0.9158 - val_f1-score: 0.9519
#
# Epoch 00005: val_iou_score did not improve from 0.92155
# Epoch 6/50
# 662/662 [==============================] - 840s 1s/step - loss: 0.0828 - iou_score: 0.9364 - f1-score: 0.9656 - val_loss: 0.1136 - val_iou_score: 0.9162 - val_f1-score: 0.9521
#
# Epoch 00006: val_iou_score did not improve from 0.92155
# Epoch 7/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0821 - iou_score: 0.9378 - f1-score: 0.9665 - val_loss: 0.1128 - val_iou_score: 0.9162 - val_f1-score: 0.9521
#
# Epoch 00007: val_iou_score did not improve from 0.92155
# Epoch 8/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0813 - iou_score: 0.9387 - f1-score: 0.9671 - val_loss: 0.1144 - val_iou_score: 0.9137 - val_f1-score: 0.9505
#
# Epoch 00008: val_iou_score did not improve from 0.92155
# Epoch 9/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0824 - iou_score: 0.9373 - f1-score: 0.9662 - val_loss: 0.1135 - val_iou_score: 0.9160 - val_f1-score: 0.9520
#
# Epoch 00009: val_iou_score did not improve from 0.92155
# Epoch 10/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0831 - iou_score: 0.9370 - f1-score: 0.9658 - val_loss: 0.1121 - val_iou_score: 0.9168 - val_f1-score: 0.9524
#
# Epoch 00010: val_iou_score did not improve from 0.92155
# Epoch 11/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0819 - iou_score: 0.9380 - f1-score: 0.9665 - val_loss: 0.1138 - val_iou_score: 0.9141 - val_f1-score: 0.9508
#
# Epoch 00011: val_iou_score did not improve from 0.92155
# Epoch 12/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0792 - iou_score: 0.9391 - f1-score: 0.9674 - val_loss: 0.1132 - val_iou_score: 0.9144 - val_f1-score: 0.9509
#
# Epoch 00012: val_iou_score did not improve from 0.92155
# Epoch 13/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0828 - iou_score: 0.9381 - f1-score: 0.9665 - val_loss: 0.1133 - val_iou_score: 0.9135 - val_f1-score: 0.9504
#
# Epoch 00013: val_iou_score did not improve from 0.92155
# Epoch 14/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0816 - iou_score: 0.9379 - f1-score: 0.9665 - val_loss: 0.1118 - val_iou_score: 0.9180 - val_f1-score: 0.9532
#
# Epoch 00014: val_iou_score did not improve from 0.92155
# Epoch 15/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0799 - iou_score: 0.9395 - f1-score: 0.9675 - val_loss: 0.1120 - val_iou_score: 0.9167 - val_f1-score: 0.9524
#
# Epoch 00015: val_iou_score did not improve from 0.92155
# Epoch 16/50
# 662/662 [==============================] - 844s 1s/step - loss: 0.0829 - iou_score: 0.9370 - f1-score: 0.9661 - val_loss: 0.1130 - val_iou_score: 0.9135 - val_f1-score: 0.9503
#
# Epoch 00016: val_iou_score did not improve from 0.92155
# Epoch 17/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0811 - iou_score: 0.9387 - f1-score: 0.9672 - val_loss: 0.1125 - val_iou_score: 0.9151 - val_f1-score: 0.9514
#
# Epoch 00017: val_iou_score did not improve from 0.92155
# Epoch 18/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0830 - iou_score: 0.9374 - f1-score: 0.9663 - val_loss: 0.1127 - val_iou_score: 0.9173 - val_f1-score: 0.9528
#
# Epoch 00018: val_iou_score did not improve from 0.92155
# Epoch 19/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0822 - iou_score: 0.9380 - f1-score: 0.9664 - val_loss: 0.1118 - val_iou_score: 0.9184 - val_f1-score: 0.9534
#
# Epoch 00019: val_iou_score did not improve from 0.92155
# Epoch 20/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0813 - iou_score: 0.9381 - f1-score: 0.9667 - val_loss: 0.1109 - val_iou_score: 0.9178 - val_f1-score: 0.9530
#
# Epoch 00020: val_iou_score did not improve from 0.92155
# Epoch 21/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0803 - iou_score: 0.9390 - f1-score: 0.9672 - val_loss: 0.1130 - val_iou_score: 0.9163 - val_f1-score: 0.9521
#
# Epoch 00021: val_iou_score did not improve from 0.92155
# Epoch 22/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0819 - iou_score: 0.9382 - f1-score: 0.9667 - val_loss: 0.1127 - val_iou_score: 0.9149 - val_f1-score: 0.9512
#
# Epoch 00022: val_iou_score did not improve from 0.92155
# Epoch 23/50
# 662/662 [==============================] - 840s 1s/step - loss: 0.0821 - iou_score: 0.9368 - f1-score: 0.9656 - val_loss: 0.1124 - val_iou_score: 0.9158 - val_f1-score: 0.9518
#
# Epoch 00023: val_iou_score did not improve from 0.92155
# Epoch 24/50
# 662/662 [==============================] - 849s 1s/step - loss: 0.0806 - iou_score: 0.9382 - f1-score: 0.9667 - val_loss: 0.1125 - val_iou_score: 0.9149 - val_f1-score: 0.9513
#
# Epoch 00024: val_iou_score did not improve from 0.92155
# Epoch 25/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0794 - iou_score: 0.9396 - f1-score: 0.9676 - val_loss: 0.1109 - val_iou_score: 0.9163 - val_f1-score: 0.9521
#
# Epoch 00025: val_iou_score did not improve from 0.92155
# Epoch 26/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0790 - iou_score: 0.9408 - f1-score: 0.9683 - val_loss: 0.1119 - val_iou_score: 0.9144 - val_f1-score: 0.9509
#
# Epoch 00026: val_iou_score did not improve from 0.92155
# Epoch 27/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0800 - iou_score: 0.9398 - f1-score: 0.9676 - val_loss: 0.1124 - val_iou_score: 0.9162 - val_f1-score: 0.9521
#
# Epoch 00027: val_iou_score did not improve from 0.92155
# Epoch 28/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0798 - iou_score: 0.9387 - f1-score: 0.9669 - val_loss: 0.1119 - val_iou_score: 0.9179 - val_f1-score: 0.9531
#
# Epoch 00028: val_iou_score did not improve from 0.92155
# Epoch 29/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0798 - iou_score: 0.9401 - f1-score: 0.9675 - val_loss: 0.1114 - val_iou_score: 0.9187 - val_f1-score: 0.9536
#
# Epoch 00029: val_iou_score did not improve from 0.92155
# Epoch 30/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0790 - iou_score: 0.9404 - f1-score: 0.9681 - val_loss: 0.1126 - val_iou_score: 0.9156 - val_f1-score: 0.9517
#
# Epoch 00030: val_iou_score did not improve from 0.92155
# Epoch 31/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0809 - iou_score: 0.9387 - f1-score: 0.9668 - val_loss: 0.1122 - val_iou_score: 0.9154 - val_f1-score: 0.9515
#
# Epoch 00031: val_iou_score did not improve from 0.92155
# Epoch 32/50
# 662/662 [==============================] - 844s 1s/step - loss: 0.0793 - iou_score: 0.9393 - f1-score: 0.9672 - val_loss: 0.1115 - val_iou_score: 0.9191 - val_f1-score: 0.9538
#
# Epoch 00032: val_iou_score did not improve from 0.92155
# Epoch 33/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0795 - iou_score: 0.9402 - f1-score: 0.9678 - val_loss: 0.1135 - val_iou_score: 0.9142 - val_f1-score: 0.9508
#
# Epoch 00033: val_iou_score did not improve from 0.92155
# Epoch 34/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0796 - iou_score: 0.9393 - f1-score: 0.9673 - val_loss: 0.1137 - val_iou_score: 0.9141 - val_f1-score: 0.9507
#
# Epoch 00034: val_iou_score did not improve from 0.92155
# Epoch 35/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0802 - iou_score: 0.9383 - f1-score: 0.9668 - val_loss: 0.1109 - val_iou_score: 0.9169 - val_f1-score: 0.9525
#
# Epoch 00035: val_iou_score did not improve from 0.92155
# Epoch 36/50
# 662/662 [==============================] - 847s 1s/step - loss: 0.0801 - iou_score: 0.9392 - f1-score: 0.9672 - val_loss: 0.1111 - val_iou_score: 0.9171 - val_f1-score: 0.9526
#
# Epoch 00036: val_iou_score did not improve from 0.92155
# Epoch 37/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0799 - iou_score: 0.9391 - f1-score: 0.9670 - val_loss: 0.1113 - val_iou_score: 0.9167 - val_f1-score: 0.9523
#
# Epoch 00037: val_iou_score did not improve from 0.92155
# Epoch 38/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0817 - iou_score: 0.9383 - f1-score: 0.9668 - val_loss: 0.1116 - val_iou_score: 0.9172 - val_f1-score: 0.9527
#
# Epoch 00038: val_iou_score did not improve from 0.92155
# Epoch 39/50
# 662/662 [==============================] - 841s 1s/step - loss: 0.0779 - iou_score: 0.9398 - f1-score: 0.9676 - val_loss: 0.1112 - val_iou_score: 0.9170 - val_f1-score: 0.9525
#
# Epoch 00039: val_iou_score did not improve from 0.92155
# Epoch 40/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0779 - iou_score: 0.9408 - f1-score: 0.9682 - val_loss: 0.1126 - val_iou_score: 0.9133 - val_f1-score: 0.9501
#
# Epoch 00040: val_iou_score did not improve from 0.92155
# Epoch 41/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0800 - iou_score: 0.9396 - f1-score: 0.9674 - val_loss: 0.1109 - val_iou_score: 0.9178 - val_f1-score: 0.9531
#
# Epoch 00041: val_iou_score did not improve from 0.92155
# Epoch 42/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0783 - iou_score: 0.9411 - f1-score: 0.9682 - val_loss: 0.1120 - val_iou_score: 0.9147 - val_f1-score: 0.9510
#
# Epoch 00042: val_iou_score did not improve from 0.92155
# Epoch 43/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0785 - iou_score: 0.9397 - f1-score: 0.9676 - val_loss: 0.1111 - val_iou_score: 0.9154 - val_f1-score: 0.9515
#
# Epoch 00043: val_iou_score did not improve from 0.92155
# Epoch 44/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0808 - iou_score: 0.9391 - f1-score: 0.9670 - val_loss: 0.1115 - val_iou_score: 0.9156 - val_f1-score: 0.9516
#
# Epoch 00044: val_iou_score did not improve from 0.92155
# Epoch 45/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0787 - iou_score: 0.9399 - f1-score: 0.9675 - val_loss: 0.1124 - val_iou_score: 0.9137 - val_f1-score: 0.9504
#
# Epoch 00045: val_iou_score did not improve from 0.92155
# Epoch 46/50
# 662/662 [==============================] - 845s 1s/step - loss: 0.0779 - iou_score: 0.9412 - f1-score: 0.9683 - val_loss: 0.1113 - val_iou_score: 0.9160 - val_f1-score: 0.9519
#
# Epoch 00046: val_iou_score did not improve from 0.92155
# Epoch 47/50
# 662/662 [==============================] - 843s 1s/step - loss: 0.0779 - iou_score: 0.9409 - f1-score: 0.9683 - val_loss: 0.1114 - val_iou_score: 0.9171 - val_f1-score: 0.9526
#
# Epoch 00047: val_iou_score did not improve from 0.92155
# Epoch 48/50
# 662/662 [==============================] - 844s 1s/step - loss: 0.0768 - iou_score: 0.9414 - f1-score: 0.9686 - val_loss: 0.1120 - val_iou_score: 0.9152 - val_f1-score: 0.9514
#
# Epoch 00048: val_iou_score did not improve from 0.92155
# Epoch 49/50
# 662/662 [==============================] - 846s 1s/step - loss: 0.0782 - iou_score: 0.9402 - f1-score: 0.9679 - val_loss: 0.1120 - val_iou_score: 0.9144 - val_f1-score: 0.9509
#
# Epoch 00049: val_iou_score did not improve from 0.92155
# Epoch 50/50
# 662/662 [==============================] - 842s 1s/step - loss: 0.0786 - iou_score: 0.9399 - f1-score: 0.9677 - val_loss: 0.1111 - val_iou_score: 0.9158 - val_f1-score: 0.9517
#
# Epoch 00050: val_iou_score did not improve from 0.92155

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

# %%
# load best weights
model.load_weights('best_model.h5')

# %%
scores = model.evaluate_generator(test_dataloader)

print("Loss: {:.5}".format(scores[0]))
for metric, value in zip(metrics, scores[1:]):
    print("mean {}: {:.5}".format(metric.__name__, value))
# Out:
# C:\Users\Gabriel\anaconda3\envs\deeplearning\lib\site-packages\tensorflow\python\keras\engine\training.py:1973: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Loss: 0.090104
# mean iou_score: 0.9408
# mean f1-score: 0.96672

# %% [markdown]
# # Visualization of results on test dataset

# %%
n = 5
ids = np.random.choice(np.arange(len(test_dataset)), size=n)

for i in ids:
    
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 0].squeeze(),
        pr_mask=pr_mask[..., 0].squeeze(),
    )
